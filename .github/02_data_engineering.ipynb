# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account.
#
# Extract all files into the directory: `./05_src/data/prices_csv/`
#
# Your folder structure should include the following paths:
#
# + `05_src/data/prices_csv/etfs`
# + `05_src/data/prices_csv/stocks`

# %%
import pandas as pd
import os
import sys
from glob import glob

sys.path.append(os.getenv('SRC_DIR'))

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to load the historical price data for stocks and ETFs, we could use:

# %%
import random

stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))

random.seed(42)
stock_files = random.sample(stock_files, 60)

dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2025-09-25 16:33:54,290, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HCM.csv
# 2025-09-25 16:33:54,372, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ATHM.csv
# 2025-09-25 16:33:54,405, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RILYP.csv
# 2025-09-25 16:33:54,412, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ALDX.csv
# 2025-09-25 16:33:54,444, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/JHG.csv
# 2025-09-25 16:33:54,461, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CHRS.csv
# 2025-09-25 16:33:54,590, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BKTI.csv
# 2025-09-25 16:33:54,635, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/REFR.csv
# 2025-09-25 16:33:54,685, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KEN.csv
# 2025-09-25 16:33:54,711, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MDRRP.csv
# 2025-09-25 16:33:54,730, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GRF.csv
# 2025-09-25 16:33:54,760, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KRC.csv
# 2025-09-25 16:33:54,798, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MICT.csv
# 2025-09-25 16:33:54,823, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMPY.csv
# 2025-09-25 16:33:54,850, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/A.csv
# 2025-09-25 16:33:54,879, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/WRLSU.csv
# 2025-09-25 16:33:54,895, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PNR.csv
# 2025-09-25 16:33:54,959, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TERP.csv
# 2025-09-25 16:33:54,977, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TMSR.csv
# 2025-09-25 16:33:54,991, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TDJ.csv
# 2025-09-25 16:33:55,009, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CIK.csv
# 2025-09-25 16:33:55,053, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SMBC.csv
# 2025-09-25 16:33:55,101, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CNSP.csv
# 2025-09-25 16:33:55,110, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BLK.csv
# 2025-09-25 16:33:55,159, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CLNC.csv
# 2025-09-25 16:33:55,188, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AOSL.csv
# 2025-09-25 16:33:55,212, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LYV.csv
# 2025-09-25 16:33:55,258, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IX.csv
# 2025-09-25 16:33:55,303, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AWRE.csv
# 2025-09-25 16:33:55,344, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KNX.csv
# 2025-09-25 16:33:55,407, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TRXC.csv
# 2025-09-25 16:33:55,478, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CVCY.csv
# 2025-09-25 16:33:55,543, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UVE.csv
# 2025-09-25 16:33:55,663, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HCKT.csv
# 2025-09-25 16:33:55,706, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TFSL.csv
# 2025-09-25 16:33:55,739, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ACB.csv
# 2025-09-25 16:33:55,811, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AXP.csv
# 2025-09-25 16:33:55,941, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GLG.csv
# 2025-09-25 16:33:55,976, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MFO.csv
# 2025-09-25 16:33:56,010, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PCB.csv
# 2025-09-25 16:33:56,041, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IPDN.csv
# 2025-09-25 16:33:56,060, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DTW.csv
# 2025-09-25 16:33:56,078, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IQV.csv
# 2025-09-25 16:33:56,100, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/EVRI.csv
# 2025-09-25 16:33:56,128, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LIVE.csv
# 2025-09-25 16:33:56,206, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/KZR.csv
# 2025-09-25 16:33:56,246, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/SO.csv
# 2025-09-25 16:33:56,325, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/INFY.csv
# 2025-09-25 16:33:56,396, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/BSE.csv
# 2025-09-25 16:33:56,461, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PSN.csv
# 2025-09-25 16:33:56,516, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TNAV.csv
# 2025-09-25 16:33:56,644, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/APTX.csv
# 2025-09-25 16:33:56,655, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LAZY.csv
# 2025-09-25 16:33:56,670, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DK.csv
# 2025-09-25 16:33:56,698, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ZEUS.csv
# 2025-09-25 16:33:56,742, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IRBT.csv
# 2025-09-25 16:33:56,776, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMAT.csv
# 2025-09-25 16:33:56,838, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PSB.csv
# 2025-09-25 16:33:56,872, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CTSO.csv
# 2025-09-25 16:33:56,893, 4121356139.py, 10, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UEC.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data:

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230273 entries, 0 to 230272
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       230273 non-null  datetime64[ns]
#  1   Open       230260 non-null  float64
#  2   High       230260 non-null  float64
#  3   Low        230260 non-null  float64
#  4   Close      230260 non-null  float64
#  5   Adj Close  230260 non-null  float64
#  6   Volume     230260 non-null  float64
#  7   source     230273 non-null  object
#  8   ticker     230273 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 15.8+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['HCM',
#  'ATHM',
#  'RILYP',
#  'ALDX',
#  'JHG',
#  'CHRS',
#  'BKTI',
#  'REFR',
#  'KEN',
#  'MDRRP',
#  'GRF',
#  'KRC',
#  'MICT',
#  'AMPY',
#  'A',
#  'WRLSU',
#  'PNR',
#  'TERP',
#  'TMSR',
#  'TDJ',
#  'CIK',
#  'SMBC',
#  'CNSP',
#  'BLK',
#  'CLNC',
#  'AOSL',
#  'LYV',
#  'IX',
#  'AWRE',
#  'KNX',
#  'TRXC',
#  'CVCY',
#  'UVE',
#  'HCKT',
#  'TFSL',
#  'ACB',
#  'AXP',
#  'GLG',
#  'MFO',
#  'PCB',
#  'IPDN',
#  'DTW',
#  'IQV',
#  'EVRI',
#  'LIVE',
#  'KZR',
#  'SO',
#  'INFY',
#  'BSE',
#  'PSN',
#  'TNAV',
#  'APTX',
#  'LAZY',
#  'DK',
#  'ZEUS',
#  'IRBT',
#  'AMAT',
#  'PSB',
#  'CTSO',
#  'UEC']

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time
import shutil

# %%
temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")
shutil.rmtree(csv_dir, ignore_errors=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")
os.makedirs(csv_dir, exist_ok=True)

# %%
start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2025-09-25 16:34:03,692, 473192941.py, 5, INFO, Writing data ((230273, 9)) to csv took 6.352592945098877 seconds.
# 2025-09-25 16:34:03,696, 473192941.py, 6, INFO, CSV file size 25.944855999999998 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2025-09-25 16:34:09,642, 817812245.py, 7, INFO, Writing dd ((230273, 9)) to parquet took 2.9803121089935303 seconds.
# 2025-09-25 16:34:09,649, 817812245.py, 8, INFO, Parquet file size 8.937065 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("ticker")

# %%
# this is to display the schema of the dataframe only, without data
dd_px
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year
# npartitions=60
# A               datetime64[ns]  float64  float64  float64  float64   float64  float64  object  int32
# ACB                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# Dask Name: sort_index, 8 graph layers

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# /var/folders/51/mcycgk1j10v6n47l_1w_g1080000gn/T/ipykernel_98814/102405636.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year Close_lag_1  Returns
# npartitions=60
# A               datetime64[ns]  float64  float64  float64  float64   float64  float64  object  int32     float64  float64
# ACB                        ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...         ...      ...
# Dask Name: assign, 14 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# ticker
# A      1999-11-18  32.546494  35.765381  28.612303  31.473534  27.068665
# A      1999-11-19  30.713520  30.758226  28.478184  28.880543  24.838577
# A      1999-11-22  29.551144  31.473534  28.657009  31.473534  27.068665
# A      1999-11-23  30.400572  31.205294  28.612303  28.612303  24.607880
# A      1999-11-24  28.701717  29.998211  28.612303  29.372318  25.261524
# ...           ...        ...        ...        ...        ...        ...
# ZEUS   2003-12-24   6.950000   7.000000   6.880000   6.990000   6.401954
# ZEUS   2003-12-26   7.000000   7.750000   6.800000   7.630000   6.988110
# ZEUS   2003-12-29   7.700000   8.500000   7.670000   8.200000   7.510161
# ZEUS   2003-12-30   8.000000   8.500000   8.000000   8.500000   7.784920
# ZEUS   2003-12-31   8.050000   8.490000   8.010000   8.210000   7.519320
#
#             Volume    source  Year  Close_lag_1   Returns
# ticker
# A       62546300.0     A.csv  1999          NaN       NaN
# A       15234100.0     A.csv  1999    31.473534 -0.082386
# A        6577800.0     A.csv  1999    28.880543  0.089783
# A        5975600.0     A.csv  1999    31.473534 -0.090909
# A        4843200.0     A.csv  1999    28.612303  0.026563
# ...            ...       ...   ...          ...       ...
# ZEUS       10700.0  ZEUS.csv  2003     6.870000  0.017467
# ZEUS      179300.0  ZEUS.csv  2003     6.990000  0.091559
# ZEUS      221700.0  ZEUS.csv  2003     7.630000  0.074705
# ZEUS       95600.0  ZEUS.csv  2003     8.200000  0.036585
# ZEUS       55400.0  ZEUS.csv  2003     8.500000 -0.034118
#
# [230273 rows x 11 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2025-09-25 16:36:03,611, data_manager.py, 53, INFO, Processing sample of tickers
# 2025-09-25 16:36:03,622, data_manager.py, 64, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2025-09-25 16:36:03,702, data_manager.py, 66, INFO, Found 8050 files in ../../05_src/data/prices/
# 2025-09-25 16:36:03,705, data_manager.py, 74, INFO, Selecting sample of files
# 2025-09-25 16:36:03,707, data_manager.py, 80, INFO, Selected 30 files
# 2025-09-25 16:36:03,709, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/LLNW.csv
# 2025-09-25 16:36:03,710, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LLNW.csv
# 2025-09-25 16:36:03,739, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:04,349, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/RILYN.csv
# 2025-09-25 16:36:04,350, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RILYN.csv
# 2025-09-25 16:36:04,358, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:04,453, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/DKS.csv
# 2025-09-25 16:36:04,454, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/DKS.csv
# 2025-09-25 16:36:04,484, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:05,256, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/JFU.csv
# 2025-09-25 16:36:05,257, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/JFU.csv
# 2025-09-25 16:36:05,268, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:05,350, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/MFA.csv
# 2025-09-25 16:36:05,351, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MFA.csv
# 2025-09-25 16:36:05,376, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:06,308, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/RILYH.csv
# 2025-09-25 16:36:06,309, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/RILYH.csv
# 2025-09-25 16:36:06,319, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:06,419, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/PUMP.csv
# 2025-09-25 16:36:06,420, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PUMP.csv
# 2025-09-25 16:36:06,431, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:06,621, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/TPRE.csv
# 2025-09-25 16:36:06,622, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TPRE.csv
# 2025-09-25 16:36:06,635, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:07,051, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/WH.csv
# 2025-09-25 16:36:07,052, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/WH.csv
# 2025-09-25 16:36:07,063, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:07,202, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/UNP.csv
# 2025-09-25 16:36:07,203, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/UNP.csv
# 2025-09-25 16:36:07,255, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:08,893, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/AMHCU.csv
# 2025-09-25 16:36:08,894, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMHCU.csv
# 2025-09-25 16:36:08,904, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:08,994, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/RFAP.csv
# 2025-09-25 16:36:08,995, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/RFAP.csv
# 2025-09-25 16:36:09,012, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:09,225, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/PB.csv
# 2025-09-25 16:36:09,226, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/PB.csv
# 2025-09-25 16:36:09,255, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:10,080, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/CVGW.csv
# 2025-09-25 16:36:10,082, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/CVGW.csv
# 2025-09-25 16:36:10,115, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:10,879, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/FRO.csv
# 2025-09-25 16:36:10,881, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/FRO.csv
# 2025-09-25 16:36:10,906, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:11,628, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/LMHB.csv
# 2025-09-25 16:36:11,629, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LMHB.csv
# 2025-09-25 16:36:11,644, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:11,852, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/XNET.csv
# 2025-09-25 16:36:11,853, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/XNET.csv
# 2025-09-25 16:36:11,869, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:12,152, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/IIIN.csv
# 2025-09-25 16:36:12,153, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/IIIN.csv
# 2025-09-25 16:36:12,191, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:13,352, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/TRVG.csv
# 2025-09-25 16:36:13,353, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TRVG.csv
# 2025-09-25 16:36:13,368, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:13,610, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/LSCC.csv
# 2025-09-25 16:36:13,611, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/LSCC.csv
# 2025-09-25 16:36:13,652, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:14,946, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/HMTV.csv
# 2025-09-25 16:36:14,949, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/HMTV.csv
# 2025-09-25 16:36:14,968, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:15,328, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/ACEL.csv
# 2025-09-25 16:36:15,329, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/ACEL.csv
# 2025-09-25 16:36:15,338, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:15,427, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/TISI.csv
# 2025-09-25 16:36:15,428, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TISI.csv
# 2025-09-25 16:36:15,466, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:17,190, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/NHF.csv
# 2025-09-25 16:36:17,191, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/NHF.csv
# 2025-09-25 16:36:17,209, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:17,768, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/AMC.csv
# 2025-09-25 16:36:17,769, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/AMC.csv
# 2025-09-25 16:36:17,784, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:18,062, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/TTMI.csv
# 2025-09-25 16:36:18,063, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/TTMI.csv
# 2025-09-25 16:36:18,095, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:18,839, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/etfs/RESD.csv
# 2025-09-25 16:36:18,840, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/etfs/RESD.csv
# 2025-09-25 16:36:18,847, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:18,880, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/GTS.csv
# 2025-09-25 16:36:18,883, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/GTS.csv
# 2025-09-25 16:36:18,902, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:19,441, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/VRA.csv
# 2025-09-25 16:36:19,442, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/VRA.csv
# 2025-09-25 16:36:19,461, data_manager.py, 101, INFO, Saving data by year
# 2025-09-25 16:36:19,863, data_manager.py, 90, INFO, Processing file ../../05_src/data/prices_csv/stocks/MDRR.csv
# 2025-09-25 16:36:19,864, data_manager.py, 118, INFO, Reading file: ../../05_src/data/prices_csv/stocks/MDRR.csv
# 2025-09-25 16:36:19,872, data_manager.py, 101, INFO, Saving data by year

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2025-09-25 16:36:20,035, data_manager.py, 131, INFO, Creating features data.
# 2025-09-25 16:36:20,038, data_manager.py, 141, INFO, Loading price data from ../../05_src/data/prices/
# 2025-09-25 16:36:54,363, data_manager.py, 150, INFO, Creating features
# /Users/doren/DSI/module5-production/production/01_materials/labs/../../05_src/stock_prices/data_manager.py:153: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd.groupby('ticker', group_keys=False)
# 2025-09-25 16:36:54,379, data_manager.py, 175, INFO, Saving features to ../../05_src/data/features/stock_features
